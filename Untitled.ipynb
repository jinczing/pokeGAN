# %%
import pickle
from skimage import io
import numpy as np
import scipy.io
import h5py

# %%
with open('./cifar-10/data_batch_1', 'rb') as o:
    _dict = pickle.load(o, encoding='bytes')
for k, v in _dict.items():
    print(k)
io.imshow(np.moveaxis(_dict[b'data'][1024].reshape(3, 32, 32), 0, -1))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-eec10793368e> in <module>
# ----> 1 with open('./cifar-10/data_batch_1', 'rb') as o:
#       2     _dict = pickle.load(o, encoding='bytes')
#       3 for k, v in _dict.items():
#       4     print(k)
#       5 io.imshow(np.moveaxis(_dict[b'data'][1024].reshape(3, 32, 32), 0, -1))
#
# FileNotFoundError: [Errno 2] No such file or directory: './cifar-10/data_batch_1'

# %%
mat = h5py.File('./dataset/stl-10/unlabeled.mat', 'r')

# %%
io.imshow(mat['X'][:, 1473].reshape(3, 96, 96).transpose())

# %%
5 // 2 ** 4
# Out:
# 0
